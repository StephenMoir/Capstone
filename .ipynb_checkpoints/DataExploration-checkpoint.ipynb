# %% [markdown]
# ## BREAST CANCER DATA EXPLORATION
#
# #### Load the required libraries

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
from scipy.stats import norm

# %%
# %matplotlib inline

# %% [markdown]
# #### Read in the data

# %%
# read in the csv file
local_data = 'data/data.csv'

# print out some data
bc_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', bc_df.shape)
print()
bc_df.head()
# Out:
# Data shape (rows, cols):  (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# features
features_list = bc_df.columns.values
print('Features: \n', features_list)
# Out:
# Features:
#  ['id' 'diagnosis' 'radius_mean' 'texture_mean' 'perimeter_mean'
#  'area_mean' 'smoothness_mean' 'compactness_mean' 'concavity_mean'
#  'concave points_mean' 'symmetry_mean' 'fractal_dimension_mean'
#  'radius_se' 'texture_se' 'perimeter_se' 'area_se' 'smoothness_se'
#  'compactness_se' 'concavity_se' 'concave points_se' 'symmetry_se'
#  'fractal_dimension_se' 'radius_worst' 'texture_worst' 'perimeter_worst'
#  'area_worst' 'smoothness_worst' 'compactness_worst' 'concavity_worst'
#  'concave points_worst' 'symmetry_worst' 'fractal_dimension_worst'
#  'Unnamed: 32']

# %% [markdown]
# #### Check for missing data

# %%
# drop the column of nulls
clean1_bc_df = bc_df.drop('Unnamed: 32', axis = 1)

print('Data shape (rows, cols): ', clean1_bc_df.shape)
clean1_bc_df.head()
# Out:
# Data shape (rows, cols):  (569, 32)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# drop any incomplete data
clean_bc_df = clean1_bc_df.dropna(axis=0)
print('Data shape (rows, cols): ', clean_bc_df.shape)
# Out:
# Data shape (rows, cols):  (569, 32)

# %% [markdown]
# #### Create a numerical outcome variable

# %%
clean_bc_df['diag_value'] = [1 if x == 'M' else 0 for x in bc_df['diagnosis']]

# %%
clean_bc_df = clean_bc_df.drop('diagnosis', axis = 1)

# %%
clean_bc_df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# #### Explore the variables

# %% [markdown]
# <b> a. Radius (mean of distances from center to points on the perimeter) </b><br>
# a1. Mean <br>
# a2. Standard Error <br>
# a3. Largest (mean of 3 largest)

# %%
# radius
radius_list = ['radius_mean', 'radius_se', 'radius_worst']
n_bins = 50 

for column_name in radius_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> b. texture (standard deviation of gray-scale values) </b><br>
# b1. Mean <br>
# b2. Standard Error <br>
# b3. Largest (mean of 3 largest)

# %%
# texture
texture_list = ['texture_mean', 'texture_se', 'texture_worst']
n_bins = 50 

for column_name in texture_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> c. perimeter </b><br>
# c1. Mean <br>
# c2. Standard Error <br>
# c3. Largest (mean of 3 largest)

# %%
# perimeter
perimeter_list = ['perimeter_mean', 'perimeter_se', 'perimeter_worst']
n_bins = 50 

for column_name in perimeter_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> d. area </b><br>
# d1. Mean <br>
# d2. Standard Error <br>
# d3. Largest (mean of 3 largest)

# %%
# area
area_list = ['area_mean', 'area_se', 'area_worst']
n_bins = 50 

for column_name in area_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> e. smoothness (local variation in radius lengths) </b><br>
# e1. Mean <br>
# e2. Standard Error <br>
# e3. Largest (mean of 3 largest)

# %%
# smoothness
smoothness_list = ['smoothness_mean', 'smoothness_se', 'smoothness_worst']
n_bins = 50 

for column_name in smoothness_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> f. compactness (perimeter^2 / area - 1.0) </b><br>
# f1. Mean <br>
# f2. Standard Error <br>
# f3. Largest (mean of 3 largest)

# %%
# compactness
compactness_list = ['compactness_mean', 'compactness_se', 'compactness_worst']
n_bins = 50 

for column_name in compactness_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> g. concavity (severity of concave portions of the contour) </b><br>
# g1. Mean <br>
# g2. Standard Error <br>
# g3. Largest (mean of 3 largest)

# %%
# concavity
concavity_list = ['concavity_mean', 'concavity_se', 'concavity_worst']
n_bins = 50 

for column_name in concavity_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> h. concave points (number of concave portions of the contour) </b><br>
# h1. Mean <br>
# h2. Standard Error <br>
# h3. Largest (mean of 3 largest)

# %%
# concave points
concave_points_list = ['concave points_mean', 'concave points_se', 'concave points_worst']
n_bins = 50 

for column_name in concave_points_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> i. symmetry </b><br>
# i1. Mean <br>
# i2. Standard Error <br>
# i3. Largest (mean of 3 largest)

# %%
# symmetry
symmetry_list = ['symmetry_mean', 'symmetry_se', 'symmetry_worst']
n_bins = 50 

for column_name in symmetry_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# <b> j. fractal dimension ("coastline approximation" - 1) : jaggedness </b><br>
# j1. Mean <br>
# j2. Standard Error <br>
# j3. Largest (mean of 3 largest)

# %%
# fractal dimension
fractal_dimension_list = ['fractal_dimension_mean', 'fractal_dimension_se', 'fractal_dimension_worst']
n_bins = 50 

for column_name in fractal_dimension_list:
    data = clean_bc_df[column_name]
    ax=plt.subplots(figsize=(6,3))
    # get data by column_name and display a histogram
    ax = plt.hist(data, bins=n_bins, density=True, alpha=0.6, color='y')
    
    # normal distribution
    mu , std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2)
    
    title="Fit results: mu = %.2f,  std = %.2f" % (mu, std) +" for " + column_name
    plt.title(title, fontsize=12)
    plt.show()

# %% [markdown]
# ### Scale the data

# %% [markdown]
# As a general rule of thumb use <br>
#     1. Standardisation when the data is approximately normally distributed <br>
#     2. Min-Max scaling when it is not
# <br>
# <br>
# Using the histograms above, it can be seen that, whilst not perfect in every case, a Standardisation can be justified

# %%
# only scale the variables - not the id or outcome
var_bc_df = clean_bc_df.loc[:,'radius_mean':'fractal_dimension_worst']
var_bc_df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# scale the data to have mean = 0 and std = 1
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()



# store them in this dataframe
scaled_bc_df = pd.DataFrame(scaler.fit_transform(var_bc_df.astype(float)))

# get same features and State-County indices
scaled_bc_df.columns=var_bc_df.columns


scaled_bc_df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Construct the scaled dataframe

# %%
scaled_final_bc_df = pd.concat([clean_bc_df['id'], scaled_bc_df, clean_bc_df['diag_value']], axis = 1, sort = False)
scaled_final_bc_df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302     1.097064     -2.073335        1.269934   0.984375
# 1    842517     1.829821     -0.353632        1.685955   1.908708
# 2  84300903     1.579888      0.456187        1.566503   1.558884
# 3  84348301    -0.768909      0.253732       -0.592687  -0.764464
# 4  84358402     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# Write to a csv file for use in PCA notebook

# %%
scaled_data = 'data/scaled.csv'
scaled_final_bc_df.to_csv(scaled_data)
